# %% [markdown]
# ## Bibliotecas

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
from google.colab import files

# %% [markdown]
# ## Coletando Dados do site da B3

# %%
def busca_carteira_teorica(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1]

# %%
def get_tickers(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

# %% [markdown]
# ## Buscando os códigos das empresas que compõem os índices e baixando as cotações do Yahoo Finance

# %% [markdown]
# ### Índices amplos

# %% [markdown]
# Índice Bovespa (Ibovespa B3)

# %%
t_ibov = get_tickers('ibov')
t_ibov
# Out:
# ['ABEV3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CPLE6.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'HAPV3.SA',
#  'HGTX3.SA',
#  'HYPE3.SA',
#  'IGTA3.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'LAME4.SA',
#  'LCAM3.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'PRIO3.SA',
#  'QUAL3.SA',
#  'RADL3.SA',
# ...

# %%
ibov = yf.download(t_ibov, period='1mo', group_by='ticker')
ibov
# Out:
# [*********************100%***********************]  82 of 82 completed
#              IGTA3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close    Volume
# Date                                         ...
# 2021-04-26  37.410000  38.990002  37.220001  ...    10.27  10.226729  19035200
# 2021-04-27  38.320000  38.549999  37.570000  ...    10.05  10.007656  24556800
# 2021-04-28  37.900002  37.900002  36.959999  ...    10.40  10.378186  54396100
# 2021-04-29  37.490002  37.689999  36.730000  ...    10.16  10.138690  30718500
# 2021-04-30  37.189999  37.799999  36.799999  ...    10.06  10.060000  43158000
# 2021-05-03  37.250000  39.349998  36.900002  ...    10.19  10.190000  29791600
# 2021-05-04  38.740002  39.130001  38.330002  ...     9.92   9.920000  60100900
# 2021-05-05  39.150002  39.770000  38.840000  ...    10.21  10.210000  34750700
# 2021-05-06  39.000000  40.279999  38.730000  ...    10.20  10.200000  25021100
# ...

# %% [markdown]
# Índice Brasil 100 (IBrX 100 B3)

# %%
t_ibrx = get_tickers('ibrx')
t_ibrx
# Out:
# ['ABEV3.SA',
#  'ALPA4.SA',
#  'ALSO3.SA',
#  'AMAR3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CESP6.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CPLE6.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSMG3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'HAPV3.SA',
#  'HGTX3.SA',
#  'HYPE3.SA',
#  'IGTA3.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LCAM3.SA',
#  'LIGT3.SA',
#  'LINX3.SA',
#  'LREN3.SA',
#  'LWSA3.SA',
# ...

# %%
ibrx = yf.download(t_ibrx, period='1mo', group_by='ticker')
ibrx
# Out:
# [*********************100%***********************]  101 of 101 completed
#              ABEV3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close    Volume
# Date                                         ...
# 2021-04-26  15.600000  15.850000  15.480000  ...    10.27  10.226729  19035200
# 2021-04-27  15.510000  15.600000  15.210000  ...    10.05  10.007656  24556800
# 2021-04-28  15.300000  15.410000  15.180000  ...    10.40  10.378186  54396100
# 2021-04-29  15.210000  15.460000  15.210000  ...    10.16  10.138690  30718500
# 2021-04-30  15.200000  15.300000  14.910000  ...    10.06  10.060000  43158000
# 2021-05-03  14.920000  14.990000  14.610000  ...    10.19  10.190000  29791600
# 2021-05-04  14.740000  14.800000  14.540000  ...     9.92   9.920000  60100900
# 2021-05-05  14.650000  14.920000  14.570000  ...    10.21  10.210000  34750700
# 2021-05-06  15.840000  16.290001  15.720000  ...    10.20  10.200000  25021100
# ...

# %% [markdown]
# Índice Brasil 50 (IBrX 50 B3)

# %%
t_ibxl = get_tickers('ibxl')
t_ibxl
# Out:
# ['ABEV3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BPAC11.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'COGN3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'ELET3.SA',
#  'EQTL3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'LAME4.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'PRIO3.SA',
#  'RADL3.SA',
#  'RAIL3.SA',
#  'RENT3.SA',
#  'SBSP3.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TOTS3.SA',
#  'UGPA3.SA',
#  'USIM5.SA',
#  'VALE3.SA',
#  'VVAR3.SA',
#  'WEGE3.SA']

# %%
ibxl = yf.download(t_ibxl, period='1mo', group_by='ticker')
ibxl
# Out:
# [*********************100%***********************]  50 of 50 completed
#              MRFG3.SA                        ...   BBDC4.SA
#                  Open       High        Low  ...      Close  Adj Close    Volume
# Date                                         ...
# 2021-04-26  20.600000  20.620001  20.020000  ...  23.549999  23.531807  35723700
# 2021-04-27  20.459999  20.500000  19.660000  ...  23.340000  23.321970  38271500
# 2021-04-28  20.100000  20.129999  18.940001  ...  24.590000  24.571003  56617500
# 2021-04-29  19.150000  19.700001  19.070000  ...  23.770000  23.751637  35143300
# 2021-04-30  19.309999  19.600000  19.090000  ...  23.850000  23.831575  58168800
# 2021-05-03  19.389999  19.420000  18.430000  ...  24.559999  24.541025  51775800
# 2021-05-04  18.930000  19.770000  18.910000  ...  23.799999  23.799999  49586800
# 2021-05-05  19.410000  19.950001  19.270000  ...  23.840000  23.840000  62797200
# ...

# %% [markdown]
# Índice Brasil Amplo BM&FBOVESPA (IBrA B3)

# %%
t_ibra = get_tickers('ibra')
t_ibra
# Out:
# ['AALR3.SA',
#  'ABCB4.SA',
#  'ABEV3.SA',
#  'ALPA4.SA',
#  'ALSO3.SA',
#  'ALUP11.SA',
#  'AMAR3.SA',
#  'ANIM3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BKBR3.SA',
#  'BMGB4.SA',
#  'BPAC11.SA',
#  'BPAN4.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR6.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CCRO3.SA',
#  'CEAB3.SA',
#  'CESP6.SA',
#  'CIEL3.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSMG3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'DMMO3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENAT3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GFSA3.SA',
# ...

# %%
ibra = yf.download(t_ibra, period='1mo', group_by='ticker')
ibra
# Out:
# [*********************100%***********************]  165 of 165 completed
#
# 2 Failed downloads:
# - TIET11.SA: No data found for this date range, symbol may be delisted
# - RLOG3.SA: No data found, symbol may be delisted
#              LJQQ3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close      Volume
# Date                                         ...
# 2021-04-26  17.180000  17.400000  16.700001  ...    10.27  10.226729  19035200.0
# 2021-04-27  16.980000  17.440001  16.559999  ...    10.05  10.007656  24556800.0
# 2021-04-28  17.110001  17.340000  16.850000  ...    10.40  10.378186  54396100.0
# 2021-04-29  16.990000  17.959999  16.930000  ...    10.16  10.138690  30718500.0
# 2021-04-30  17.799999  18.360001  17.430000  ...    10.06  10.060000  43158000.0
# 2021-05-02        NaN        NaN        NaN  ...      NaN        NaN         NaN
# 2021-05-03  18.889999  18.900000  18.360001  ...    10.19  10.190000  29791600.0
# ...

# %% [markdown]
# ### Índices de Governança

# %% [markdown]
# Índice de Ações com Governança Corporativa Diferenciada (IGC B3)

# %%
t_igc = get_tickers('igc')
t_igc
# Out:
# ['AALR3.SA',
#  'ABCB4.SA',
#  'AERI3.SA',
#  'AGRO3.SA',
#  'ALPA3.SA',
#  'ALPA4.SA',
#  'ALPK3.SA',
#  'ALSO3.SA',
#  'ALUP11.SA',
#  'AMAR3.SA',
#  'AMBP3.SA',
#  'ANIM3.SA',
#  'APER3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AVLL3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBRK3.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BKBR3.SA',
#  'BMEB3.SA',
#  'BMEB4.SA',
#  'BMGB4.SA',
#  'BMOB3.SA',
#  'BOAS3.SA',
#  'BPAC11.SA',
#  'BPAN4.SA',
#  'BRAP3.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR3.SA',
#  'BRSR6.SA',
#  'BSEV3.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CARD3.SA',
#  'CASH3.SA',
#  'CCPR3.SA',
#  'CCRO3.SA',
#  'CEAB3.SA',
#  'CEDO3.SA',
#  'CEDO4.SA',
#  'CESP3.SA',
#  'CESP6.SA',
#  'CIEL3.SA',
#  'CLSC4.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CMIN3.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
# ...

# %%
igc = yf.download(t_igc, period='1mo', group_by='ticker')
igc
# Out:
# [*********************100%***********************]  239 of 239 completed
#
# 2 Failed downloads:
# - TIET11.SA: No data found for this date range, symbol may be delisted
# - RLOG3.SA: No data found, symbol may be delisted
#            ENAT3.SA                    ... ITSA4.SA
#                Open       High    Low  ...    Close  Adj Close      Volume
# Date                                   ...
# 2021-04-26    16.25  16.290001  15.82  ...    10.27  10.226729  19035200.0
# 2021-04-27    15.96  16.129999  15.41  ...    10.05  10.007656  24556800.0
# 2021-04-28    15.55  15.860000  15.48  ...    10.40  10.378186  54396100.0
# 2021-04-29    15.87  16.299999  15.43  ...    10.16  10.138690  30718500.0
# 2021-04-30    15.43  15.560000  15.07  ...    10.06  10.060000  43158000.0
# 2021-05-02      NaN        NaN    NaN  ...      NaN        NaN         NaN
# 2021-05-03    15.02  15.060000  14.47  ...    10.19  10.190000  29791600.0
# ...

# %% [markdown]
# Índice de Ações com Tag Along Diferenciado (ITAG B3)

# %%
t_itag = get_tickers('itag')
t_itag
# Out:
# ['AALR3.SA',
#  'ABCB4.SA',
#  'AERI3.SA',
#  'AGRO3.SA',
#  'ALPK3.SA',
#  'ALSO3.SA',
#  'ALUP11.SA',
#  'AMAR3.SA',
#  'AMBP3.SA',
#  'ANIM3.SA',
#  'APER3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AVLL3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BAHI3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBRK3.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BGIP4.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BIOM3.SA',
#  'BKBR3.SA',
#  'BMGB4.SA',
#  'BMOB3.SA',
#  'BOAS3.SA',
#  'BPAC11.SA',
#  'BPAN4.SA',
#  'BRAP3.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR3.SA',
#  'BRSR6.SA',
#  'BSEV3.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CARD3.SA',
#  'CASH3.SA',
#  'CCPR3.SA',
#  'CCRO3.SA',
#  'CEAB3.SA',
#  'CEDO4.SA',
#  'CESP6.SA',
#  'CGRA3.SA',
#  'CGRA4.SA',
#  'CIEL3.SA',
#  'CLSC4.SA',
#  'CMIN3.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CRDE3.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSED3.SA',
#  'CSMG3.SA',
# ...

# %%
itag = yf.download(t_itag, period='1mo', group_by='ticker')
itag
# Out:
# [*********************100%***********************]  228 of 228 completed
#
# 2 Failed downloads:
# - TIET11.SA: No data found for this date range, symbol may be delisted
# - RLOG3.SA: No data found, symbol may be delisted
#              CARD3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close      Volume
# Date                                         ...
# 2021-04-26  26.400000  26.760000  25.950001  ...    10.27  10.226729  19035200.0
# 2021-04-27  26.790001  27.030001  25.120001  ...    10.05  10.007656  24556800.0
# 2021-04-28  25.440001  26.719999  25.440001  ...    10.40  10.378186  54396100.0
# 2021-04-29  26.520000  26.980000  25.320000  ...    10.16  10.138690  30718500.0
# 2021-04-30  25.680000  26.639999  25.670000  ...    10.06  10.060000  43158000.0
# 2021-05-02        NaN        NaN        NaN  ...      NaN        NaN         NaN
# 2021-05-03  26.280001  26.530001  25.459999  ...    10.19  10.190000  29791600.0
# ...

# %% [markdown]
# Índice de Governança Corporativa Trade (IGCT B3)

# %%
t_igct = get_tickers('igct')
t_igct
# Out:
# ['AALR3.SA',
#  'ABCB4.SA',
#  'ALPA4.SA',
#  'ALSO3.SA',
#  'ALUP11.SA',
#  'AMAR3.SA',
#  'ANIM3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BKBR3.SA',
#  'BMGB4.SA',
#  'BPAC11.SA',
#  'BPAN4.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR6.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CCRO3.SA',
#  'CEAB3.SA',
#  'CESP6.SA',
#  'CIEL3.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSMG3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENAT3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GFSA3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
# ...

# %%
igct = yf.download(t_igct, period='1mo', group_by='ticker')
igct
# Out:
# [*********************100%***********************]  156 of 156 completed
#
# 2 Failed downloads:
# - TIET11.SA: No data found for this date range, symbol may be delisted
# - RLOG3.SA: No data found, symbol may be delisted
#            ENAT3.SA                    ... ITSA4.SA
#                Open       High    Low  ...    Close  Adj Close      Volume
# Date                                   ...
# 2021-04-26    16.25  16.290001  15.82  ...    10.27  10.226729  19035200.0
# 2021-04-27    15.96  16.129999  15.41  ...    10.05  10.007656  24556800.0
# 2021-04-28    15.55  15.860000  15.48  ...    10.40  10.378186  54396100.0
# 2021-04-29    15.87  16.299999  15.43  ...    10.16  10.138690  30718500.0
# 2021-04-30    15.43  15.560000  15.07  ...    10.06  10.060000  43158000.0
# 2021-05-02      NaN        NaN    NaN  ...      NaN        NaN         NaN
# 2021-05-03    15.02  15.060000  14.47  ...    10.19  10.190000  29791600.0
# ...

# %% [markdown]
# Índice de Governança Corporativa – Novo Mercado (IGC-NM B3)

# %%
t_ignm = get_tickers('ignm')
t_ignm
# Out:
# ['AALR3.SA',
#  'AERI3.SA',
#  'AGRO3.SA',
#  'ALPK3.SA',
#  'ALSO3.SA',
#  'AMAR3.SA',
#  'AMBP3.SA',
#  'ANIM3.SA',
#  'APER3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'AVLL3.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBRK3.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BKBR3.SA',
#  'BMOB3.SA',
#  'BOAS3.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BSEV3.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CARD3.SA',
#  'CASH3.SA',
#  'CCPR3.SA',
#  'CCRO3.SA',
#  'CEAB3.SA',
#  'CIEL3.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSED3.SA',
#  'CSMG3.SA',
#  'CURY3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'DMVF3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELMD3.SA',
#  'EMBR3.SA',
#  'ENAT3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENJU3.SA',
#  'EQTL3.SA',
#  'ESPA3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GFSA3.SA',
#  'GMAT3.SA',
#  'GNDI3.SA',
#  'GRND3.SA',
#  'GSHP3.SA',
#  'HAPV3.SA',
#  'HBOR3.SA',
# ...

# %%
ignm = yf.download(t_ignm, period='1mo', group_by='ticker')
ignm
# Out:
# [*********************100%***********************]  168 of 168 completed
#
# 1 Failed download:
# - RLOG3.SA: No data found, symbol may be delisted
#            ENAT3.SA                    ...   JBSS3.SA
#                Open       High    Low  ...      Close  Adj Close      Volume
# Date                                   ...
# 2021-04-26    16.25  16.290001  15.82  ...  35.369999  34.232746  15681900.0
# 2021-04-27    15.96  16.129999  15.41  ...  33.689999  32.606762  18536400.0
# 2021-04-28    15.55  15.860000  15.48  ...  31.620001  30.603321  32725700.0
# 2021-04-29    15.87  16.299999  15.43  ...  30.799999  30.799999  18866700.0
# 2021-04-30    15.43  15.560000  15.07  ...  30.120001  30.120001  18828700.0
# 2021-05-02      NaN        NaN    NaN  ...        NaN        NaN         NaN
# 2021-05-03    15.02  15.060000  14.47  ...  29.740000  29.740000  12429400.0
# 2021-05-04    14.59  14.740000  14.34  ...  30.459999  30.459999  13950900.0
# ...

# %% [markdown]
# ### Índices de Sustentabilidade

# %% [markdown]
# Índice Carbono Eficiente (ICO2 B3)

# %%
t_ico2 = get_tickers('ico2')
t_ico2
# Out:
# ['ABEV3.SA',
#  'ASAI3.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'CPFE3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'CSMG3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'ENBR3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GOLL4.SA',
#  'HYPE3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LCAM3.SA',
#  'LIGT3.SA',
#  'LREN3.SA',
#  'MDIA3.SA',
#  'MGLU3.SA',
#  'MOVI3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'NEOE3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'PSSA3.SA',
#  'RADL3.SA',
#  'RAIL3.SA',
#  'RENT3.SA',
#  'SANB11.SA',
#  'SAPR11.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TIMS3.SA',
#  'TRPL4.SA',
#  'UGPA3.SA',
#  'VIVT3.SA',
#  'WEGE3.SA']

# %%
ico2 = yf.download(t_ico2, period='1mo', group_by='ticker')
ico2
# Out:
# [*********************100%***********************]  63 of 63 completed
#              MRFG3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close    Volume
# Date                                         ...
# 2021-04-26  20.600000  20.620001  20.020000  ...    10.27  10.226729  19035200
# 2021-04-27  20.459999  20.500000  19.660000  ...    10.05  10.007656  24556800
# 2021-04-28  20.100000  20.129999  18.940001  ...    10.40  10.378186  54396100
# 2021-04-29  19.150000  19.700001  19.070000  ...    10.16  10.138690  30718500
# 2021-04-30  19.309999  19.600000  19.090000  ...    10.06  10.060000  43158000
# 2021-05-03  19.389999  19.420000  18.430000  ...    10.19  10.190000  29791600
# 2021-05-04  18.930000  19.770000  18.910000  ...     9.92   9.920000  60100900
# 2021-05-05  19.410000  19.950001  19.270000  ...    10.21  10.210000  34750700
# 2021-05-06  20.000000  20.180000  19.000000  ...    10.20  10.200000  25021100
# ...

# %% [markdown]
# Índice de Sustentabilidade Empresarial (ISE B3)

# %%
t_ise = get_tickers('ise')
t_ise
# Out:
# ['ASAI3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CSAN3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'ENBR3.SA',
#  'FLRY3.SA',
#  'ITSA4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'KLBN11.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LIGT3.SA',
#  'LREN3.SA',
#  'MDIA3.SA',
#  'MOVI3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'NEOE3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'SANB11.SA',
#  'SUZB3.SA',
#  'TIET11.SA',
#  'TIMS3.SA',
#  'VIVT3.SA',
#  'WEGE3.SA']

# %%
ise = yf.download(t_ise, period='1mo', group_by='ticker')
ise
# Out:
# [*********************100%***********************]  47 of 47 completed
#
# 1 Failed download:
# - TIET11.SA: No data found for this date range, symbol may be delisted
#              BPAC11.SA                          ... ITSA4.SA
#                   Open        High         Low  ...    Close  Adj Close    Volume
# Date                                            ...
# 2021-04-26  100.029999  102.870003  100.000000  ...    10.27  10.226729  19035200
# 2021-04-27  102.000000  107.239998  101.559998  ...    10.05  10.007656  24556800
# 2021-04-28  104.870003  107.169998  104.790001  ...    10.40  10.378186  54396100
# 2021-04-29  107.199997  107.239998  105.040001  ...    10.16  10.138690  30718500
# 2021-04-30  105.419998  108.139999  103.879997  ...    10.06  10.060000  43158000
# 2021-05-03  109.489998  112.059998  108.610001  ...    10.19  10.190000  29791600
# 2021-05-04  111.900002  111.970001  106.709999  ...     9.92   9.920000  60100900
# ...

# %% [markdown]
# ### Índices de Segmentos e Setoriais

# %% [markdown]
# Índice BM&FBOVESPA Financeiro (IFNC B3)

# %%
t_ifnc = get_tickers('ifnc')
t_ifnc
# Out:
# ['ABCB4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BMGB4.SA',
#  'BPAC11.SA',
#  'BPAN4.SA',
#  'BRSR6.SA',
#  'CIEL3.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'PSSA3.SA',
#  'SANB11.SA',
#  'SULA11.SA']

# %%
ifnc = yf.download(t_ifnc, period='1mo', group_by='ticker')
ifnc
# Out:
# [*********************100%***********************]  20 of 20 completed
#              BPAC11.SA                          ...   BBDC4.SA
#                   Open        High         Low  ...      Close  Adj Close    Volume
# Date                                            ...
# 2021-04-26  100.029999  102.870003  100.000000  ...  23.549999  23.531807  35723700
# 2021-04-27  102.000000  107.239998  101.559998  ...  23.340000  23.321970  38271500
# 2021-04-28  104.870003  107.169998  104.790001  ...  24.590000  24.571003  56617500
# 2021-04-29  107.199997  107.239998  105.040001  ...  23.770000  23.751637  35143300
# 2021-04-30  105.419998  108.139999  103.879997  ...  23.850000  23.831575  58168800
# 2021-05-03  109.489998  112.059998  108.610001  ...  24.559999  24.541025  51775800
# 2021-05-04  111.900002  111.970001  106.709999  ...  23.799999  23.799999  49586800
# 2021-05-05  108.519997  110.699997  107.389999  ...  23.840000  23.840000  62797200
# ...

# %% [markdown]
# Índice de BDRs Não Patrocinados-GLOBAL (BDRX B3)

# %%
t_bdrx = get_tickers('bdrx')
t_bdrx
# Out:
# ['A1BM34.SA',
#  'A1MD34.SA',
#  'A1PA34.SA',
#  'AALL34.SA',
#  'AAPL34.SA',
#  'ABBV34.SA',
#  'ABTT34.SA',
#  'ABUD34.SA',
#  'ADBE34.SA',
#  'AMGN34.SA',
#  'AMZO34.SA',
#  'ARMT34.SA',
#  'ATTB34.SA',
#  'ATVI34.SA',
#  'AVGO34.SA',
#  'AXPB34.SA',
#  'B1SX34.SA',
#  'BABA34.SA',
#  'BBYY34.SA',
#  'BCSA34.SA',
#  'BERK34.SA',
#  'BIDU34.SA',
#  'BIIB34.SA',
#  'BKNG34.SA',
#  'BLAK34.SA',
#  'BMYB34.SA',
#  'BOAC34.SA',
#  'BOEI34.SA',
#  'BONY34.SA',
#  'BOXP34.SA',
#  'C1CL34.SA',
#  'CHCM34.SA',
#  'CHVX34.SA',
#  'CMCS34.SA',
#  'COCA34.SA',
#  'COPH34.SA',
#  'COTY34.SA',
#  'COWC34.SA',
#  'CSCO34.SA',
#  'CTGP34.SA',
#  'CVSH34.SA',
#  'DEAI34.SA',
#  'DGCO34.SA',
#  'DISB34.SA',
#  'EAIN34.SA',
#  'EBAY34.SA',
#  'EQIX34.SA',
#  'EXXO34.SA',
#  'F1NI34.SA',
#  'F1RI34.SA',
#  'FBOK34.SA',
#  'FCXO34.SA',
#  'FDMO34.SA',
#  'FDXB34.SA',
#  'GEOO34.SA',
#  'GILD34.SA',
#  'GMCO34.SA',
#  'GOGL34.SA',
#  'GOGL35.SA',
#  'GPRO34.SA',
#  'GSGI34.SA',
#  'HALI34.SA',
# ...

# %%
bdrx = yf.download(t_bdrx, period='1mo', group_by='ticker')
bdrx
# Out:
# [*********************100%***********************]  128 of 128 completed
#             COTY34.SA                        ...   C1CL34.SA
#                  Open       High        Low  ...       Close   Adj Close Volume
# Date                                         ...
# 2021-04-26  27.340000  27.340000  26.320000  ...  150.250000  150.250000  28935
# 2021-04-27  28.000000  28.180000  27.709999  ...  151.979996  151.979996  12843
# 2021-04-28  27.420000  27.840000  27.420000  ...  149.300003  149.300003  31401
# 2021-04-29  28.059999  28.059999  27.170000  ...  145.100006  145.100006   9728
# 2021-04-30  28.080000  28.080000  26.980000  ...  151.800003  151.800003   3561
# 2021-05-03  26.980000  27.600000  26.980000  ...  151.750000  151.750000   4909
# 2021-05-04  27.340000  27.340000  27.200001  ...  144.800003  144.800003   2675
# 2021-05-05  27.180000  27.180000  26.219999  ...  142.000000  142.000000   5954
# ...

# %% [markdown]
# Índice de Consumo (ICON B3)

# %%
t_icon = get_tickers('icon')
t_icon
# Out:
# ['AALR3.SA',
#  'ABEV3.SA',
#  'ALPA4.SA',
#  'AMAR3.SA',
#  'ANIM3.SA',
#  'ARZZ3.SA',
#  'ASAI3.SA',
#  'BEEF3.SA',
#  'BKBR3.SA',
#  'BRFS3.SA',
#  'BTOW3.SA',
#  'CAML3.SA',
#  'CEAB3.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CRFB3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GFSA3.SA',
#  'GNDI3.SA',
#  'GRND3.SA',
#  'GUAR3.SA',
#  'HAPV3.SA',
#  'HBOR3.SA',
#  'HGTX3.SA',
#  'HYPE3.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LCAM3.SA',
#  'LEVE3.SA',
#  'LJQQ3.SA',
#  'LREN3.SA',
#  'MDIA3.SA',
#  'MEAL3.SA',
#  'MGLU3.SA',
#  'MOVI3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MTRE3.SA',
#  'MYPK3.SA',
#  'NTCO3.SA',
#  'ODPV3.SA',
#  'PARD3.SA',
#  'PCAR3.SA',
#  'QUAL3.SA',
#  'RADL3.SA',
#  'RENT3.SA',
#  'SEER3.SA',
#  'SLCE3.SA',
#  'SMLS3.SA',
#  'SMTO3.SA',
#  'SOMA3.SA',
#  'TCSA3.SA',
#  'TEND3.SA',
#  'TRIS3.SA',
#  'VIVA3.SA',
#  'VULC3.SA',
#  'VVAR3.SA',
#  'YDUQ3.SA']

# %%
icon = yf.download(t_icon, period='1mo', group_by='ticker')
icon
# Out:
# [*********************100%***********************]  65 of 65 completed
#              SMLS3.SA                        ...   CRFB3.SA
#                  Open       High        Low  ...      Close  Adj Close     Volume
# Date                                         ...
# 2021-04-26  21.850000  21.950001  21.570000  ...  22.090000  22.090000  3243300.0
# 2021-04-27  21.879999  21.879999  21.309999  ...  21.740000  21.740000  2266000.0
# 2021-04-28  21.400000  21.629999  21.400000  ...  21.910000  21.910000  2780600.0
# 2021-04-29  21.580000  21.799999  21.459999  ...  22.180000  22.180000  2116400.0
# 2021-04-30  21.610001  21.709999  21.350000  ...  21.719999  21.719999  3489900.0
# 2021-05-02        NaN        NaN        NaN  ...        NaN        NaN        NaN
# 2021-05-03  21.469999  21.690001  21.270000  ...  21.270000  21.270000  3707100.0
# 2021-05-04  21.370001  21.490000  21.120001  ...  21.129999  21.129999  2722200.0
# ...

# %% [markdown]
# Índice de Energia Elétrica (IEE B3)

# %%
t_iee = get_tickers('iee')
t_iee
# Out:
# ['ALUP11.SA',
#  'CESP6.SA',
#  'CMIG4.SA',
#  'COCE5.SA',
#  'CPFE3.SA',
#  'CPLE6.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'LIGT3.SA',
#  'NEOE3.SA',
#  'OMGE3.SA',
#  'TAEE11.SA',
#  'TIET11.SA',
#  'TRPL4.SA']

# %%
iee = yf.download(t_iee, period='1mo', group_by='ticker')
iee
# Out:
# [*********************100%***********************]  18 of 18 completed
#
# 1 Failed download:
# - TIET11.SA: No data found for this date range, symbol may be delisted
#              EGIE3.SA                        ...   ENEV3.SA
#                  Open       High        Low  ...      Close  Adj Close    Volume
# Date                                         ...
# 2021-04-26  42.299999  42.470001  41.610001  ...  15.680000  15.680000   6079300
# 2021-04-27  41.830002  41.889999  41.240002  ...  15.270000  15.270000   4783500
# 2021-04-28  41.369999  41.830002  41.160000  ...  15.250000  15.250000   5934200
# 2021-04-29  41.470001  41.750000  41.250000  ...  15.080000  15.080000   4874800
# 2021-04-30  41.450001  41.700001  40.669998  ...  14.670000  14.670000  25459900
# 2021-05-03  40.860001  41.209999  40.529999  ...  14.700000  14.700000  10962200
# 2021-05-04  41.270000  41.270000  40.099998  ...  14.580000  14.580000   7462300
# ...

# %% [markdown]
# Índice de Fundos de Investimentos Imobiliários (IFIX B3)

# %%
t_ifix = get_tickers('ifix')
t_ifix
# Out:
# ['ABCP11.SA',
#  'ALZR11.SA',
#  'BARI11.SA',
#  'BBFI11B.SA',
#  'BBPO11.SA',
#  'BCFF11.SA',
#  'BCIA11.SA',
#  'BCRI11.SA',
#  'BPFF11.SA',
#  'BRCO11.SA',
#  'BRCR11.SA',
#  'BTCR11.SA',
#  'BTLG11.SA',
#  'CPFF11.SA',
#  'CPTS11.SA',
#  'CVBI11.SA',
#  'FIGS11.SA',
#  'FIIB11.SA',
#  'FLMA11.SA',
#  'GGRC11.SA',
#  'GTWR11.SA',
#  'HABT11.SA',
#  'HCTR11.SA',
#  'HFOF11.SA',
#  'HGBS11.SA',
#  'HGCR11.SA',
#  'HGFF11.SA',
#  'HGLG11.SA',
#  'HGPO11.SA',
#  'HGRE11.SA',
#  'HGRU11.SA',
#  'HSML11.SA',
#  'HTMX11.SA',
#  'IRDM11.SA',
#  'JSRE11.SA',
#  'KFOF11.SA',
#  'KNCR11.SA',
#  'KNHY11.SA',
#  'KNIP11.SA',
#  'KNRI11.SA',
#  'LVBI11.SA',
#  'MALL11.SA',
#  'MCCI11.SA',
#  'MFII11.SA',
#  'MGFF11.SA',
#  'MXRF11.SA',
#  'OUJP11.SA',
#  'OULG11.SA',
#  'PATC11.SA',
#  'PATL11.SA',
#  'PLCR11.SA',
#  'PVBI11.SA',
#  'QAGR11.SA',
#  'RBED11.SA',
#  'RBFF11.SA',
#  'RBRF11.SA',
#  'RBRP11.SA',
#  'RBRR11.SA',
#  'RBVA11.SA',
#  'RCRB11.SA',
#  'RECR11.SA',
#  'RECT11.SA',
# ...

# %%
ifix = yf.download(t_ifix, period='1mo', group_by='ticker')
ifix
# Out:
# [*********************100%***********************]  87 of 87 completed
#             PATL11.SA                        ... FLMA11.SA
#                  Open       High        Low  ...     Close Adj Close  Volume
# Date                                         ...
# 2021-04-26        NaN        NaN        NaN  ...      2.77      2.77   65841
# 2021-04-27        NaN        NaN        NaN  ...      2.80      2.80   47237
# 2021-04-28        NaN        NaN        NaN  ...      2.78      2.78   36759
# 2021-04-29        NaN        NaN        NaN  ...      2.79      2.79   50720
# 2021-04-30        NaN        NaN        NaN  ...      2.82      2.82   51836
# 2021-05-03        NaN        NaN        NaN  ...      2.85      2.85   53831
# 2021-05-04        NaN        NaN        NaN  ...      2.84      2.84   67034
# 2021-05-05        NaN        NaN        NaN  ...      2.86      2.86   44124
# 2021-05-06        NaN        NaN        NaN  ...      2.86      2.86   45591
# ...

# %% [markdown]
# Índice de Materiais Básicos BM&FBOVESPA (IMAT B3)

# %%
t_imat = get_tickers('imat')
t_imat
# Out:
# ['BRAP4.SA',
#  'BRKM5.SA',
#  'CSNA3.SA',
#  'DTEX3.SA',
#  'GGBR4.SA',
#  'GOAU4.SA',
#  'KLBN11.SA',
#  'SUZB3.SA',
#  'UNIP6.SA',
#  'USIM5.SA',
#  'VALE3.SA']

# %%
imat = yf.download(t_ise, period='1mo', group_by='ticker')
imat
# Out:
# [*********************100%***********************]  47 of 47 completed
#
# 1 Failed download:
# - TIET11.SA: No data found for this date range, symbol may be delisted
#              BPAC11.SA                          ...   BBDC4.SA
#                   Open        High         Low  ...      Close  Adj Close    Volume
# Date                                            ...
# 2021-04-26  100.029999  102.870003  100.000000  ...  23.549999  23.531807  35723700
# 2021-04-27  102.000000  107.239998  101.559998  ...  23.340000  23.321970  38271500
# 2021-04-28  104.870003  107.169998  104.790001  ...  24.590000  24.571003  56617500
# 2021-04-29  107.199997  107.239998  105.040001  ...  23.770000  23.751637  35143300
# 2021-04-30  105.419998  108.139999  103.879997  ...  23.850000  23.831575  58168800
# 2021-05-03  109.489998  112.059998  108.610001  ...  24.559999  24.541025  51775800
# 2021-05-04  111.900002  111.970001  106.709999  ...  23.799999  23.799999  49586800
# ...

# %% [markdown]
# Índice Dividendos BM&FBOVESPA (IDIV B3)

# %%
t_idiv = get_tickers('idiv')
t_idiv
# Out:
# ['ABCB4.SA',
#  'BBAS3.SA',
#  'BBSE3.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRSR6.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CSMG3.SA',
#  'CSNA3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'EGIE3.SA',
#  'ENBR3.SA',
#  'ITSA4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'KLBN11.SA',
#  'LEVE3.SA',
#  'MRVE3.SA',
#  'MYPK3.SA',
#  'PSSA3.SA',
#  'QUAL3.SA',
#  'ROMI3.SA',
#  'SANB11.SA',
#  'SAPR11.SA',
#  'SAPR4.SA',
#  'SLCE3.SA',
#  'SMLS3.SA',
#  'TAEE11.SA',
#  'TGMA3.SA',
#  'TIET11.SA',
#  'TRPL4.SA',
#  'UNIP6.SA',
#  'VIVT3.SA',
#  'WIZS3.SA']

# %%
idiv = yf.download(t_idiv, period='1mo', group_by='ticker')
idiv
# Out:
# [*********************100%***********************]  39 of 39 completed
#
# 1 Failed download:
# - TIET11.SA: No data found for this date range, symbol may be delisted
#              SMLS3.SA                        ...   SLCE3.SA
#                  Open       High        Low  ...      Close  Adj Close   Volume
# Date                                         ...
# 2021-04-26  21.850000  21.950001  21.570000  ...  49.840000  48.813339   727800
# 2021-04-27  21.879999  21.879999  21.309999  ...  50.419998  49.381390  1310700
# 2021-04-28  21.400000  21.629999  21.400000  ...  50.290001  49.254070   720300
# 2021-04-29  21.580000  21.799999  21.459999  ...  51.590000  50.527290  1233400
# 2021-04-30  21.610001  21.709999  21.350000  ...  48.790001  48.790001  1145300
# 2021-05-03  21.469999  21.690001  21.270000  ...  50.799999  50.799999  3284500
# 2021-05-04  21.370001  21.490000  21.120001  ...  50.900002  50.900002  1223200
# ...

# %% [markdown]
# Índice do Setor Industrial (INDX B3)

# %%
t_indx = get_tickers('indx')
t_indx
# Out:
# ['ABEV3.SA',
#  'ALPA4.SA',
#  'BEEF3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'CAML3.SA',
#  'CSNA3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'DTEX3.SA',
#  'EMBR3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'GFSA3.SA',
#  'GGBR4.SA',
#  'GOAU4.SA',
#  'GRND3.SA',
#  'HBOR3.SA',
#  'HGTX3.SA',
#  'JBSS3.SA',
#  'JHSF3.SA',
#  'KLBN11.SA',
#  'MDIA3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MYPK3.SA',
#  'NTCO3.SA',
#  'POMO4.SA',
#  'POSI3.SA',
#  'RAPT4.SA',
#  'SMTO3.SA',
#  'SUZB3.SA',
#  'TASA4.SA',
#  'TCSA3.SA',
#  'TEND3.SA',
#  'TRIS3.SA',
#  'TUPY3.SA',
#  'USIM5.SA',
#  'VIVA3.SA',
#  'WEGE3.SA']

# %%
indx = yf.download(t_indx, period='1mo', group_by='ticker')
indx
# Out:
# [*********************100%***********************]  40 of 40 completed
#              CYRE3.SA                        ...   JBSS3.SA
#                  Open       High        Low  ...      Close  Adj Close      Volume
# Date                                         ...
# 2021-04-26  24.580000  25.080000  24.309999  ...  35.369999  34.232746  15681900.0
# 2021-04-27  24.459999  24.690001  24.200001  ...  33.689999  32.606762  18536400.0
# 2021-04-28  24.360001  24.530001  23.719999  ...  31.620001  30.603321  32725700.0
# 2021-04-29  24.490000  24.760000  23.940001  ...  30.799999  30.799999  18866700.0
# 2021-04-30  24.000000  24.280001  23.520000  ...  30.120001  30.120001  18828700.0
# 2021-05-03  23.629999  24.090000  23.410000  ...  29.740000  29.740000  12429400.0
# 2021-05-04  23.559999  23.670000  23.290001  ...  30.459999  30.459999  13950900.0
# 2021-05-05  23.440001  23.879999  23.080000  ...  31.049999  31.049999   9913400.0
# ...

# %% [markdown]
# Índice Imobiliário (IMOB B3)

# %%
t_imob = get_tickers('imob')
t_imob
# Out:
# ['ALSO3.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'GFSA3.SA',
#  'HBOR3.SA',
#  'IGTA3.SA',
#  'JHSF3.SA',
#  'JPSA3.SA',
#  'LOGG3.SA',
#  'LPSB3.SA',
#  'MRVE3.SA',
#  'MTRE3.SA',
#  'MULT3.SA',
#  'TCSA3.SA',
#  'TEND3.SA',
#  'TRIS3.SA']

# %%
imob = yf.download(t_imob, period='1mo', group_by='ticker')
imob
# Out:
# [*********************100%***********************]  20 of 20 completed
#              LOGG3.SA                        ...   MRVE3.SA
#                  Open       High        Low  ...      Close  Adj Close   Volume
# Date                                         ...
# 2021-04-26  29.480000  29.870001  29.180000  ...  17.910000  17.634649  4034100
# 2021-04-27  29.719999  30.070000  29.000000  ...  17.850000  17.575573  2284100
# 2021-04-28  29.000000  30.240000  28.830000  ...  17.629999  17.358953  3691800
# 2021-04-29  30.500000  31.719999  30.040001  ...  17.600000  17.329416  2894000
# 2021-04-30  30.090000  30.370001  29.500000  ...  17.350000  17.350000  6642800
# 2021-05-03  29.590000  30.549999  29.450001  ...  17.219999  17.219999  2365000
# 2021-05-04  30.480000  30.650000  29.420000  ...  16.980000  16.980000  3636800
# 2021-05-05  29.570000  30.040001  29.510000  ...  17.129999  17.129999  3053900
# ...

# %% [markdown]
# Índice MidLarge Cap (MLCX B3)

# %%
t_mlcx = get_tickers('mlcx')
t_mlcx
# Out:
# ['ABEV3.SA',
#  'ALPA4.SA',
#  'ASAI3.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'BPAC11.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSNA3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'ITSA4.SA',
#  'ITUB3.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'LAME3.SA',
#  'LAME4.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'NEOE3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'PSSA3.SA',
#  'RADL3.SA',
#  'RAIL3.SA',
#  'RENT3.SA',
#  'SANB11.SA',
#  'SBSP3.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TIMS3.SA',
#  'TOTS3.SA',
#  'TRPL4.SA',
#  'UGPA3.SA',
#  'VALE3.SA',
#  'VIVT3.SA',
#  'VVAR3.SA',
#  'WEGE3.SA']

# %%
mlcx = yf.download(t_mlcx, period='1mo', group_by='ticker')
mlcx
# Out:
# [*********************100%***********************]  64 of 64 completed
#            HAPV3.SA                ...   CRFB3.SA
#                Open   High    Low  ...      Close  Adj Close     Volume
# Date                               ...
# 2021-04-26    14.78  14.95  14.64  ...  22.090000  22.090000  3243300.0
# 2021-04-27    14.76  14.87  14.47  ...  21.740000  21.740000  2266000.0
# 2021-04-28    14.51  14.82  14.16  ...  21.910000  21.910000  2780600.0
# 2021-04-29    14.74  14.95  14.59  ...  22.180000  22.180000  2116400.0
# 2021-04-30    14.68  14.86  14.38  ...  21.719999  21.719999  3489900.0
# 2021-05-03    14.43  15.04  14.42  ...  21.270000  21.270000  3707100.0
# 2021-05-04    14.96  15.05  14.73  ...  21.129999  21.129999  2722200.0
# 2021-05-05    14.99  14.99  14.70  ...  21.650000  21.650000  4695700.0
# 2021-05-06    14.70  14.88  14.65  ...  21.100000  21.100000  2506100.0
# 2021-05-07    14.83  15.34  14.80  ...  21.490000  21.490000  3231200.0
# ...

# %% [markdown]
# Índice Small Cap (SMLL B3)

# %%
t_smll = get_tickers('smll')
t_smll
# Out:
# ['AALR3.SA',
#  'ABCB4.SA',
#  'ALSO3.SA',
#  'ALUP11.SA',
#  'AMAR3.SA',
#  'ANIM3.SA',
#  'ARZZ3.SA',
#  'AZUL4.SA',
#  'BEEF3.SA',
#  'BKBR3.SA',
#  'BMGB4.SA',
#  'BPAN4.SA',
#  'BRML3.SA',
#  'BRPR3.SA',
#  'BRSR6.SA',
#  'CAML3.SA',
#  'CCPR3.SA',
#  'CEAB3.SA',
#  'CESP6.SA',
#  'CIEL3.SA',
#  'CNTO3.SA',
#  'COGN3.SA',
#  'CSMG3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'DIRR3.SA',
#  'DMMO3.SA',
#  'DTEX3.SA',
#  'ECOR3.SA',
#  'EMBR3.SA',
#  'ENAT3.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'EVEN3.SA',
#  'EZTC3.SA',
#  'FLRY3.SA',
#  'GFSA3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'GRND3.SA',
#  'GUAR3.SA',
#  'HBOR3.SA',
#  'HGTX3.SA',
#  'IGTA3.SA',
#  'IRBR3.SA',
#  'JHSF3.SA',
#  'JPSA3.SA',
#  'LCAM3.SA',
#  'LEVE3.SA',
#  'LIGT3.SA',
#  'LINX3.SA',
#  'LJQQ3.SA',
#  'LOGG3.SA',
#  'LOGN3.SA',
#  'LPSB3.SA',
#  'LWSA3.SA',
#  'MDIA3.SA',
#  'MEAL3.SA',
#  'MILS3.SA',
#  'MOVI3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MTRE3.SA',
#  'MULT3.SA',
#  'MYPK3.SA',
#  'ODPV3.SA',
# ...

# %%
smll = yf.download(t_smll, period='1mo', group_by='ticker')
smll
# Out:
# [*********************100%***********************]  101 of 101 completed
#
# 2 Failed downloads:
# - TIET11.SA: No data found for this date range, symbol may be delisted
# - RLOG3.SA: No data found, symbol may be delisted
#              LJQQ3.SA                        ... POSI3.SA
#                  Open       High        Low  ...    Close  Adj Close      Volume
# Date                                         ...
# 2021-04-26  17.180000  17.400000  16.700001  ...    11.95  11.585779   8624800.0
# 2021-04-27  16.980000  17.440001  16.559999  ...    10.87  10.538696  18119200.0
# 2021-04-28  17.110001  17.340000  16.850000  ...    11.06  10.722906  14148800.0
# 2021-04-29  16.990000  17.959999  16.930000  ...    11.09  10.751991   7254000.0
# 2021-04-30  17.799999  18.360001  17.430000  ...    11.23  10.887724   5652800.0
# 2021-05-02        NaN        NaN        NaN  ...      NaN        NaN         NaN
# 2021-05-03  18.889999  18.900000  18.360001  ...    10.33  10.330000   8518300.0
# ...

# %% [markdown]
# Índice Utilidade Pública BM&FBOVESPA (UTIL B3)

# %%
t_util = get_tickers('util')
t_util
# Out:
# ['ALUP11.SA',
#  'CESP6.SA',
#  'CMIG3.SA',
#  'CMIG4.SA',
#  'CPFE3.SA',
#  'CPLE3.SA',
#  'CPLE6.SA',
#  'CSMG3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'ENBR3.SA',
#  'ENEV3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'LIGT3.SA',
#  'NEOE3.SA',
#  'OMGE3.SA',
#  'SAPR11.SA',
#  'SAPR4.SA',
#  'SBSP3.SA',
#  'TAEE11.SA',
#  'TIET11.SA',
#  'TRPL4.SA']

# %%
util = yf.download(t_util, period='1mo', group_by='ticker')
util
# Out:
# [*********************100%***********************]  24 of 24 completed
#
# 1 Failed download:
# - TIET11.SA: No data found for this date range, symbol may be delisted
#              TRPL4.SA                        ...  ALUP11.SA
#                  Open       High        Low  ...      Close  Adj Close   Volume
# Date                                         ...
# 2021-04-26  26.120001  26.200001  25.709999  ...  26.760000  25.914312  1308400
# 2021-04-27  25.910000  25.980000  25.690001  ...  26.580000  25.740000  1661100
# 2021-04-28  25.940001  26.350000  25.709999  ...  25.870001  25.870001   707400
# 2021-04-29  26.260000  27.270000  26.150000  ...  26.799999  26.799999  1915300
# 2021-04-30  26.860001  27.230000  26.170000  ...  26.639999  26.639999  1240900
# 2021-05-03  27.000000  27.330000  26.620001  ...  26.990000  26.990000  1324500
# 2021-05-04  26.700001  26.870001  25.200001  ...  26.670000  26.670000   883900
# ...

# %% [markdown]
# Índice Valor BM&FBOVESPA (IVBX 2 B3)

# %%
t_ivbx = get_tickers('ivbx')
t_ivbx
# Out:
# ['AZUL4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'COGN3.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'ELET3.SA',
#  'EMBR3.SA',
#  'EQTL3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'HAPV3.SA',
#  'HYPE3.SA',
#  'ITSA4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'LAME4.SA',
#  'LREN3.SA',
#  'MRFG3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PRIO3.SA',
#  'QUAL3.SA',
#  'RADL3.SA',
#  'RAIL3.SA',
#  'RENT3.SA',
#  'SBSP3.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TIMS3.SA',
#  'TOTS3.SA',
#  'UGPA3.SA',
#  'USIM5.SA',
#  'VIVT3.SA',
#  'YDUQ3.SA']

# %%
ivbx = yf.download(t_ivbx, period='1mo', group_by='ticker')
ivbx
# Out:
# [*********************100%***********************]  50 of 50 completed
#              HYPE3.SA                        ... ITSA4.SA
#                  Open       High        Low  ...    Close  Adj Close      Volume
# Date                                         ...
# 2021-04-26  35.750000  36.389999  34.709999  ...    10.27  10.226729  19035200.0
# 2021-04-27  34.799999  35.049999  34.430000  ...    10.05  10.007656  24556800.0
# 2021-04-28  34.549999  34.750000  34.049999  ...    10.40  10.378186  54396100.0
# 2021-04-29  34.750000  35.470001  34.599998  ...    10.16  10.138690  30718500.0
# 2021-04-30  34.869999  35.040001  34.320000  ...    10.06  10.060000  43158000.0
# 2021-05-03  34.259998  35.110001  33.709999  ...    10.19  10.190000  29791600.0
# 2021-05-04  34.500000  34.680000  34.090000  ...     9.92   9.920000  60100900.0
# 2021-05-05  34.439999  34.779999  33.980000  ...    10.21  10.210000  34750700.0
# ...

# %% [markdown]
# ## Salvando os Dados em um Arquivo CSV

# %%
ibov.to_csv('ibov.csv')
files.download('ibov.csv')

# %%
ibrx.to_csv('ibrx.csv')
files.download('ibrx.csv')

# %%
ibxl.to_csv('ibxl.csv')
files.download('ibxl.csv')

# %%
ibra.to_csv('ibra.csv')
files.download('ibra.csv')

# %%
igc.to_csv('igc.csv')
files.download('igc.csv')

# %%
itag.to_csv('itag.csv')
files.download('itag.csv')

# %%
igct.to_csv('igct.csv')
files.download('igct.csv')

# %%
ignm.to_csv('ignm.csv')
files.download('ignm.csv')

# %%
ico2.to_csv('ico2.csv')
files.download('ico2.csv')

# %%
ise.to_csv('ise.csv')
files.download('ise.csv')

# %%
ifnc.to_csv('ifnc.csv')
files.download('ifnc.csv')

# %%
bdrx.to_csv('bdrx.csv')
files.download('bdrx.csv')

# %%
icon.to_csv('icon.csv')
files.download('icon.csv')

# %%
iee.to_csv('iee.csv')
files.download('iee.csv')

# %%
ifix.to_csv('ifix.csv')
files.download('ifix.csv')

# %%
imat.to_csv('imat.csv')
files.download('imat.csv')

# %%
idiv.to_csv('idiv.csv')
files.download('idiv.csv')

# %%
indx.to_csv('indx.csv')
files.download('indx.csv')

# %%
imob.to_csv('imob.csv')
files.download('imob.csv')

# %%
mlcx.to_csv('mlcx.csv')
files.download('mlcx.csv')

# %%
smll.to_csv('smll.csv')
files.download('smll.csv')

# %%
util.to_csv('util.csv')
files.download('util.csv')

# %%
ivbx.to_csv('ivbx.csv')
files.download('ivbx.csv')

# %% [markdown]
# ## Salvando os Dados em uma Planilha Excel

# %%
ibov.to_excel('ibov.xlsx')
files.download('ibov.xlsx')

# %%
ibrx.to_excel('ibrx.xlsx')
files.download('ibrx.xlsx')

# %%
ibxl.to_excel('ibxl.xlsx')
files.download('ibxl.xlsx')

# %%
ibra.to_excel('ibra.xlsx')
files.download('ibra.xlsx')

# %%
igc.to_excel('igc.xlsx')
files.download('igc.xlsx')

# %%
itag.to_excel('itag.xlsx')
files.download('itag.xlsx')

# %%
igct.to_excel('igct.xlsx')
files.download('igct.xlsx')

# %%
ignm.to_excel('ignm.xlsx')
files.download('ignm.xlsx')

# %%
ico2.to_excel('ico2.xlsx')
files.download('ico2.xlsx')

# %%
ise.to_excel('ise.xlsx')
files.download('ise.xlsx')

# %%
ifnc.to_excel('ifnc.xlsx')
files.download('ifnc.xlsx')

# %%
bdrx.to_excel('bdrx.xlsx')
files.download('bdrx.xlsx')

# %%
icon.to_excel('icon.xlsx')
files.download('icon.xlsx')

# %%
iee.to_excel('iee.xlsx')
files.download('iee.xlsx')

# %%
ifix.to_excel('ifix.xlsx')
files.download('ifix.xlsx')

# %%
imat.to_excel('imat.xlsx')
files.download('imat.xlsx')

# %%
idiv.to_excel('idiv.xlsx')
files.download('idiv.xlsx')

# %%
indx.to_excel('indx.xlsx')
files.download('indx.xlsx')

# %%
imob.to_excel('imob.xlsx')
files.download('imob.xlsx')

# %%
mlcx.to_excel('mlcx.xlsx')
files.download('mlcx.xlsx')

# %%
smll.to_excel('smll.xlsx')
files.download('smll.xlsx')

# %%
util.to_excel('util.xlsx')
files.download('util.xlsx')

# %%
ivbx.to_excel('ivbx.xlsx')
files.download('ivbx.xlsx')
